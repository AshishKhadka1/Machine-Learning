# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishKhadka1/Machine-Learning/blob/main/2_2_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# programming Used for ML:
# 1. Python
# 2. R

# %% [markdown]
# # **Print** **Function**

# %%
print ("Machine Learning")
# Out:
# Machine Learning

# %%
print ("Machine" + " Learning" + " Projects")
# Out:
# Machine Learning Projects

# %%
print (8)
# Out:
# 8

# %%
print (8 + 3)
# Out:
# 11

# %% [markdown]
# # **Basic** **Data** **Types**
# 1. int
# 2. float
# 3. Str

# %%
type(8)
# Out:
# int

# %%
type(5.3)
# Out:
# float

# %%
type("English")
# Out:
# str

# %% [markdown]
# #**Constant** & **Variables**

# %%
superhero = "Tron Man"
print(superhero)
# Out:
# Tron Man

# %%
hero1, hero2, hero3 = "Iron man", "Suerman", "Batman"
print(hero1)
print(hero2)
print(hero3)
# Out:
# Iron man
# Suerman
# Batman

# %% [markdown]
# #**Input Function**

# %%
number_1 = int(input("Enter a first number: "))
number_2 = int(input("Enter a second number: "))

sum = number_1 + number_2
print(sum)
# Out:
# Enter a first number: 12
# Enter a second number: 12
# 24

# %%
#changing number in python
num = 5
print(float(num))
# Out:
# 5.0
