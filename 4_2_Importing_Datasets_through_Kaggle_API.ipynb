# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishKhadka1/Machine-Learning/blob/main/4_2_Importing_Datasets_through_Kaggle_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # API - Application Programming Interface

# %%
# installing the kaggle library
# !pip install kaggle

# %% [markdown]
# Upload your kaggle.json file

# %%
#configuring the path of Kaggle.json file
# Upload file
from google.colab import files
files.upload()

# Create correct directory
# !mkdir -p ~/.kaggle

# Move file
# !cp kaggle.json ~/.kaggle/

# Set permission
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-cf23a596-2b54-4e2d-97db-deef82c7cf0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf23a596-2b54-4e2d-97db-deef82c7cf0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Verify file exists
# !ls ~/.kaggle
# Out:
# kaggle.json

# %%
# Test authentication
# !kaggle datasets list
# Out:
# ref                                                              title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# nalisha/job-salary-prediction-dataset                            Job Salary Prediction Dataset                          3144815  2026-03-16 19:54:33.843000           5458        134                1
# ssssws/chocolate-sales-dataset-2023-2024                         Chocolate Sales Dataset 2023 - 2024                   24420255  2026-03-07 04:58:02.387000           9101        143                1
# ...

# %% [markdown]
# **Importing the Earthquake Dataset**

# %%
# API to fetch the dataset from Kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction --force
# Out:
# ...
# 100% 2.27G/2.27G [00:22<00:00, 110MB/s]

# %%
# extracting the compressed Dataset
from zipfile import ZipFile
dataset = '/content/LANL-Earthquake-Prediction.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5963/1347093016.py in <cell line: 0>()
#       3 dataset = '/content/train.csv.zip'
#       4
# ----> 5 with ZipFile(dataset,'r') as zip:
#       6   zip.extractall()
#       7   print('The dataset is extracted')
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1350             while True:
#    1351                 try:
# -> 1352                     self.fp = io.open(file, filemode)
#    1353                 except OSError:
#    1354                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/train.csv.zip'
