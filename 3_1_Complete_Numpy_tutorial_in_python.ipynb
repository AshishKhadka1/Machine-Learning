# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishKhadka1/Machine-Learning/blob/main/3_1_Complete_Numpy_tutorial_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NumPy - Numerical methods**

# %% [markdown]
# Advantages of Numpy Arrays:
# 1. Allows several Mathematical Operations

# %%
import numpy as np
